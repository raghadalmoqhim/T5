# %% [markdown]
# <a href="https://colab.research.google.com/github/raghadalmoqhim/T5/blob/main/Creating_new_Feature_from_Raw_Data_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Let's see the Data set!**

# %%
df = pd.read_csv('/content/drive/MyDrive/T5/WEEK_2/LAB_Day2/Dataset/500_Person_Gender_Height_Weight_Index.csv')
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %% [markdown]
# This data set have 4 Coulmns Gender , height , weight and index.
# if we want to create a new feature , we should do some mathmatical opreation in the data set to create a new feature (new column)
#
#
# ### **what about bmi? (عامود لحساب كتلة الجسم)**
#
# ### **bmi = weight ÷ Height^2 (in meter)**
# the height in this data set not in meter
# so we need to convert it from CM to M
# to do this we need to create new coulmn :
#
# ### **height / 100 **

# %%
df['Height_M'] = df['Height'] / 100

# %%
df['Height'] = df['Height'] / 100

# %% [markdown]
# ### **Let's see what we got!**

# %%
df.head()
# Out:
#    Gender  Height  Weight  Index  Height_M
# 0    Male     174      96      4      1.74
# 1    Male     189      87      2      1.89
# 2  Female     185     110      4      1.85
# 3  Female     195     104      3      1.95
# 4    Male     149      61      3      1.49

# %% [markdown]
# Now we can create new feature from this dataset.
# as we mentioned before we want to caluclate bmi
#
# ### **bmi = weight ÷ Height^2 (in meter)**

# %%
df['BMI'] = df['Weight'] / (df['Height_M'] ** 2)

# %%
df['BMI'] = df['Weight'] / (df['Height'] ** 2)

# %% [markdown]
# ### **Let's see what we got!!!**

# %%
df.head()
# Out:
#    Gender  Height  Weight  Index        BMI
# 0    Male    1.74      96      4  31.708284
# 1    Male    1.89      87      2  24.355421
# 2  Female    1.85     110      4  32.140248
# 3  Female    1.95     104      3  27.350427
# 4    Male    1.49      61      3  27.476240

# %% [markdown]
# ### **Well done , you just created new feature from Raw Data. :) **
